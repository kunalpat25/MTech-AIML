# %% [markdown]
# # Assignment 2 - Text Search and Spelling Correction

# %% [markdown]
# Generated dataset files:

# %%
import os
os.listdir('data')
# Out:
# record3.txt
# report1.docx
# report3.docx
# record2.txt
# record1.txt
# study2.pdf
# study1.pdf
# guidelines1.csv
# guidelines2.csv
# report2.docx

# %% [markdown]
# ## Token counts during preprocessing

# %%
print('Before preprocessing:', {stats['before']})
print('After stopword removal:', {stats['stop_removed']})
print('After normalization:', {stats['normalized']})
print('After stemming:', {stats['stemmed']})
# Out:
# Before preprocessing: 1454
# After stopword removal: 1150
# After normalization: 1150
# After stemming: 1150

# %% [markdown]
# ## Inverted index (sorted)

# %%
for term, docs in sorted_index.items():
    print(term, '->', docs)
# Out:
# 45 -> ['guidelines1.csv', 'guidelines2.csv', 'record1.txt', 'record2.txt', 'record3.txt', 'report1.docx', 'report2.docx', 'report3.docx', 'study1.pdf', 'study2.pdf']
# abnormaliti -> ['guidelines1.csv', 'guidelines2.csv', 'record1.txt', 'record2.txt', 'record3.txt', 'report1.docx', 'report2.docx', 'report3.docx', 'study1.pdf', 'study2.pdf']
# about -> ['guidelines1.csv', 'guidelines2.csv', 'record1.txt', 'record2.txt', 'record3.txt', 'report1.docx', 'report2.docx', 'report3.docx', 'study1.pdf', 'study2.pdf']
# activity -> ['guidelines1.csv', 'guidelines2.csv', 'record1.txt', 'record2.txt', 'record3.txt', 'report1.docx', 'report2.docx', 'report3.docx', 'study1.pdf', 'study2.pdf']
# additional -> ['guidelines1.csv', 'guidelines2.csv', 'record1.txt', 'record2.txt', 'record3.txt', 'report1.docx', 'report2.docx', 'report3.docx', 'study1.pdf', 'study2.pdf']
# ...

# %% [markdown]
# ## Spelling correction suggestions

# %%
print('Suggestions for hypertensoin:', suggest('hypertensoin'))
# Out:
# Suggestions for hypertensoin: ['hypertensoin', 'hypertension', 'alert', 'maintain', 'pain']

# %% [markdown]
# ## Soundex demonstration

# %%
print('diabetis:', soundex('diabetis'))
print('diabetes:', soundex('diabetes'))
# Out:
# diabetis: D132
# diabetes: D132
